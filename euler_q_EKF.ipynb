# %%
from quaternion_filters import quaternion
import numpy as np
from sympy import *
from collections import OrderedDict

# %%
def euler2q(roll, pitch, heading):
    q = quaternion.Quaternion.axis_angle(np.array([0, 0, 1.]), heading)
    q = q*quaternion.Quaternion.axis_angle(np.array([0, 1., 0]), pitch)
    q = q*quaternion.Quaternion.axis_angle(np.array([1., 0, 0]), roll)
    return q

def eulers(q):
    """
    returns: roll, pitch, heading
    """
    a, b, c, d = q.a, q.b, q.c, q.d
    phi = atan2(2*(a*b + c*d),
                        1-2*(b**2 + c**2))
    theta = asin(2*(a*c - d*b))
    psi = atan2(2*(a*d+b*c),
                        1-2*(c**2+d**2))
    return np.array([phi, theta, psi])


def normalize_heading_deg(val_deg):
    if val_deg > 360:
        return normalize_heading(val_deg - 360)
    elif val_deg < 0:
        return normalize_heading(val_deg + 360)
    else:
        return val_deg

# %%
roll, pitch, heading = symbols(['roll', 'pitch', 'heading'])
wx, wy, wz = symbols(['wx', 'wy', 'wz'])
ax, ay, az = symbols(['ax', 'ay', 'az'])
mx, my, mz = symbols(['mx', 'my', 'mz'])
G = symbols('G')
dt = symbols('dt')

state = [roll, pitch, heading, ax, ay, az, wx, wy, wz]

quaternion.arctan2 = atan2  # Make quaternion use symbolic functions
quaternion.arcsin = asin
quaternion.sqrt = sqrt
quaternion.sin = sin
quaternion.cos = cos

# %%
# Which way is ac for roll
def test():
    heading = 335*np.pi/180
    roll = 60*np.pi/180
    pitch = 0*5*np.pi/180
    q = euler2q(roll, pitch, heading)
    print(eulers(q)*180/np.pi)

    a = np.array([0,0,-G]) + np.array([-sin(heading), cos(heading), 0])*G*tan(roll)

    ab = (q.inv()*quaternion.Quaternion.from_vec(a)*q).as_ndarray()[1:]
    print("body a", ab)
#test()

# Do rotations go the right way?
def test():
    heading = 135*np.pi/180
    roll = 0*np.pi/180
    pitch = 0*5*np.pi/180
    q = euler2q(roll, pitch, heading)
    wx = 10*np.pi/180
    wy = 10*np.pi/180
    wz = 10*np.pi/180
    dt = .1
    qdelta = quaternion.Quaternion(1, wx/2*dt, wy/2*dt, wz/2*dt)
    #print(eulers(q)*180/np.pi)
    qnext = q * qdelta
    
    print("roll pitch heading", eulers(qnext))
    
test()
# Out:
# roll pitch heading [1.00892971901171 0.991322812393154
#  -43.9822113375784 + 57.2957795130823*pi]

# %%
q = euler2q(roll, pitch, heading)

qdelta = quaternion.Quaternion(1, wx/2*dt, wy/2*dt, wz/2*dt)  # small angle approximation of rotation
qnext = q*qdelta

a = np.array([0,0,-G]) + np.array([-sin(heading), cos(heading), 0])*G*tan(roll)

ab = (q.inv()*quaternion.Quaternion.from_vec(a)*q).as_ndarray()[1:]

#wpredict = (q.inv()*quaternion.Quaternion.from_vec([0,0,-G/tas*tan(phi)])*q).as_ndarray()[1:]
wpredict = [wx, wy, wz]
statenext = np.concatenate([eulers(qnext), ab, wpredict])
#statenext = np.array([x.subs(q0**2+q1**2+q2**2+q3**2,1) for x in statenext])
for n in range(len(state)):
    print(f"{state[n]}_next = {statenext[n]}")
# Out:
# roll_next = atan2(2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) + 2*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)), -2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 - 2*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + 1)
# pitch_next = -asin(2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 2*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))
# heading_next = atan2(2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + 2*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)), -2*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2 - 2*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + 1)
# ax_next = (1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-G*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*sin(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - G*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - G*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) + 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*cos(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)) + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(G*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*sin(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - G*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*cos(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + G*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) + 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)) - (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(-G*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + G*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*cos(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2 ...
# ay_next = (1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(G*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*cos(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + G*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - G*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) + 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*sin(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)) + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-G*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + G*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*cos(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + G*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*sin(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)) + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(G*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*sin(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - G*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*cos(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*si ...
# az_next = (1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-G*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + G*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*cos(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + G*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*sin(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(G*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*cos(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + G*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - G*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) + 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*sin(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)) + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(-G*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*sin(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - G*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1 ...
# wx_next = wx
# wy_next = wy
# wz_next = wz

# %%
F = np.zeros((len(state), len(state)), dtype=object)
for n in range(len(state)):
    for m in range(len(state)):
        tmp = (diff(statenext[n], state[m]))
        F[n, m] = tmp
        if tmp != 0:
            print(f"F[{n}, {m}] = {tmp}")
# Out:
# F[0, 0] = (-2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) - 2*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))*(-2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(dt*wx*(0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - sin(roll/2)*cos(heading/2)*cos(pitch/2)/2) - dt*wy*(-0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 0.5*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + dt*wz*(0.5*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 0.5*sin(pitch/2)*sin(roll/2)*cos(heading/2)) + sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) - 2*(dt*wx*(-0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 0.5*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + dt*wy*(0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - sin(roll/2)*cos(heading/2)*cos(pitch/2)/2) - dt*wz*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2)) + sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))/((2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) + 2*(-dt*wx*(1.0*sin(heading/2)*sin(ro ...
# F[0, 1] = (-2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) - 2*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))*(-2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(dt*wx*(0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - sin(pitch/2)*cos(heading/2)*cos(roll/2)/2) - dt*wy*(-0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2)) + dt*wz*(-0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2)) - 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 2*(dt*wx*(-0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2)) + dt*wy*(0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - sin(pitch/2)*cos(heading/2)*cos(roll/2)/2) - dt*wz*(-0.5*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 0.5*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))/((2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) + 2*(-dt*wx*(1.0*sin(heading ...
# F[0, 2] = (-2*(dt*wx*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2)) + dt*wy*(-sin(heading/2)*cos(pitch/2)*cos(roll/2)/2 + 0.5*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - dt*wz*(-0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 0.5*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + sin(roll/2)*cos(heading/2)*cos(pitch/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - 2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(dt*wx*(-sin(heading/2)*cos(pitch/2)*cos(roll/2)/2 + 0.5*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - dt*wy*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2)) + dt*wz*(-0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2)) - 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))*(-2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) - 2*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))/((2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) + 2*(-dt*wx*(1.0*sin(heading ...
# F[0, 6] = (-2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) - 2*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))*(-2*dt*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2)) - 2*dt*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))/((2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) + 2*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(headi ...
# F[0, 7] = (-2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) - 2*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))*(-2*dt*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + 2*dt*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2)))/((2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) + 2*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(headi ...
# F[0, 8] = (-2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) - 2*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))*(2*dt*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - 2*dt*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2)))/((2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) + 2*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(h ...
# F[1, 0] = -((dt*wx*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2)) + dt*wy*(0.5*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 0.5*sin(pitch/2)*sin(roll/2)*cos(heading/2)) + dt*wz*(-0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 0.5*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + sin(roll/2)*cos(heading/2)*cos(pitch/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + (dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - 2.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 2.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(0.5*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 0.5*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + dt*wz*(0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - sin(roll/2)*cos(heading/2)*cos(pitch/2)/2)/2 - 0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 0.5*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + (dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2)) + dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 2.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 2*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(dt*wx*(-0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 0.5*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - sin(roll/2)*cos(heading/2)*cos(pitch/2)/2)/2 - dt*wz*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 0.5*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 0.5*sin(pitch/2)*sin(roll/2)*cos(heading/2)) + (dt*wx*(0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - sin(roll/2)*cos(heading/2)*cos(pitch/2)/2) - dt*wy*(-0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 0.5*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + dt*wz*(0.5*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 0.5*sin(pitch/2)*sin(roll/2)*cos(heading/2)) + sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)))/sqrt(1 - (2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 2*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/ ...
# F[1, 1] = -((-dt*wx*(-0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + dt*wy*(-0.5*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 0.5*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - sin(pitch/2)*cos(heading/2)*cos(roll/2)/2)/2 - 0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - 2.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 2.0*sin(roll/2)*cos(heading/2)*cos(pitch/2)) + (dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2)) + dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 2.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 2*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(dt*wx*(-0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wy*(0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - sin(pitch/2)*cos(heading/2)*cos(roll/2)/2)/2 - dt*wz*(-0.5*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 0.5*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 - 0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2)) + (dt*wx*(0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - sin(pitch/2)*cos(heading/2)*cos(roll/2)/2) - dt*wy*(-0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2)) + dt*wz*(-0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2)) - 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) + (dt*wx*(-0.5*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 0.5*sin(pitch/2)*sin(roll/2)*cos(heading/2)) + dt*wy*(-0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2)) + dt*wz*(-0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2)) - 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + sin(pitch/2)*cos(heading/2)*cos(roll/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))/sqrt(1 - (2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 2*(-dt*wx*(-1.0*sin(heading ...
# F[1, 2] = -((dt*wx*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + dt*wy*(-sin(heading/2)*cos(pitch/2)*cos(roll/2)/2 + 0.5*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 - dt*wz*(-0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 0.5*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2)) + dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 2.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 2*cos(heading/2)*cos(pitch/2)*cos(roll/2)) + (dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - 2.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 2.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(-0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wy*(-0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 0.5*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wz*(-sin(heading/2)*cos(pitch/2)*cos(roll/2)/2 + 0.5*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2)) + (dt*wx*(-0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 0.5*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + dt*wy*(-0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2)) + dt*wz*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2)) + sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + (-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(-sin(heading/2)*cos(pitch/2)*cos(roll/2)/2 + 0.5*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - dt*wy*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2)) + dt*wz*(-0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2)) - 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))/sqrt(1 - (2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 2*(-dt*wx*(-1.0*sin(heading ...
# F[1, 6] = -(dt*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) + dt*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - dt*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - 2.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 2.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2)) + dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 2.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 2*cos(heading/2)*cos(pitch/2)*cos(roll/2))/2)/sqrt(1 - (2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 2*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))**2)
# F[1, 7] = -(dt*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2)) + dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 2.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 2*cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + dt*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - 2.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 2.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - dt*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)))/sqrt(1 - (2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 2*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))**2)
# F[1, 8] = -(dt*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2)) - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - 2.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 2.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2)) + dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) + dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 2.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 2*cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + dt*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) + dt*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))/sqrt(1 - (2*(dt*wx*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wy*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - 1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-dt*wx*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 + dt*wy*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + dt*wz*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 + 1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - 2*(-dt*wx*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 - dt*wy*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/2 - dt*wz*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + 1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(dt*wx*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/2 + dt*wy*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/2 - dt*wz*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/2 + 1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))**2)
# ...
# F[5, 0] = (-0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(G*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*cos(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + G*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - G*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) + 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*sin(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)) + (1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(G*(-0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*cos(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - G*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(sin(heading/2)*sin(pitch/2)*cos(roll/2) - sin(roll/2)*cos(heading/2)*cos(pitch/2)) - (sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2)) - (-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)**2 - G*(0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - sin(roll/2)*cos(heading/2)*cos(pitch/2)/2)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + G*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(tan(roll)**2 + 1)*cos(heading)/((1.0*s ...
# F[5, 1] = (-0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-G*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*sin(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - G*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - G*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) + 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*cos(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)) + (1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(G*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*sin(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - G*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-(-1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(sin(heading/2)*sin(roll/2)*cos(pitch/2) - sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)**2 + G*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-(-1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(sin(heading/2)*sin(roll/2)*cos(pitch/2) - sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin( ...
# F[5, 2] = (0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(G*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*sin(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - G*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*cos(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + G*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) + 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)) + (1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-G*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-sin(heading/2)*cos(pitch/2)*cos(roll/2) + sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + sin(roll/2)*cos(heading/2)*cos(pitch/2))*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)**2 + G*(0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2))*sin(heading)*tan(roll)/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + G*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-sin(heading/2)*cos(pitch/2)*cos(roll/2) + sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + sin(roll/2)*cos(heading/2)*cos(pitch/2))*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos( ...
# F[6, 6] = 1
# F[7, 7] = 1
# F[8, 8] = 1

# %%
subexpres = {sin(pitch/2): 0, cos(pitch/2): 1}
for m in range(len(state)):
    for n in range(len(state)):
        for k, v in subexpres.items():
            F[m, n] = F[m, n].subs(k, v)
            
subexprs, subs = cse(F.flatten())
subs = np.reshape(subs, (9, 9))

for se in subexprs:
    print(f"{se[0]} = {(se[1])}")
    
for n in range(len(state)):
    for m in range(len(state)):
        tmp = subs[n, m]
        if tmp != 0:
            print(f"F[{n}, {m}] = {(tmp)}")
# Out:
# x0 = heading/2
# x1 = sin(x0)
# x2 = roll/2
# x3 = cos(x2)
# x4 = x1*x3
# x5 = sin(x2)
# x6 = x1*x5
# x7 = 0.5*x6
# x8 = dt*x7
# x9 = wx*x8
# x10 = -x9
# x11 = cos(x0)
# x12 = x11*x5
# x13 = x12/2
# x14 = dt*wy
# x15 = x11*x3
# x16 = 0.5*x15
# x17 = dt*wz
# x18 = x16*x17
# x19 = -x18
# x20 = x10 - x13*x14 + x19 + x4
# x21 = 1.0*x6
# x22 = 0.5*x4
# x23 = dt*x22
# x24 = wx*x23
# x25 = dt*x15
# x26 = wy*x25
# x27 = 0.5*x12
# x28 = dt*x27
# x29 = wz*x28
# x30 = -x29
# x31 = x21 + x24 + x26/2 + x30
# x32 = 2*x31
# x33 = -x20*x32
# x34 = dt*wx
# x35 = wy*x8
# x36 = wz*x23
# x37 = x35 + x36
# x38 = -x13*x34 + x15 + x37
# x39 = 1.0*x12
# x40 = wx*x25
# x41 = wz*x8
# x42 = wy*x23
# x43 = x41 - x42
# x44 = x39 + x40/2 + x43
# x45 = 2*x44
# x46 = 1 - 2*x31**2
# x47 = -2*x44**2 + x46
# x48 = -wx*x28 + x15
# x49 = -x35 + x48
# x50 = -x36 + x49
# x51 = x45*x50
# x52 = 1.0*x4
# x53 = wz*x25
# x54 = wy*x28
# x55 = x10 + x54
# x56 = x52 + x53/2 + x55
# x57 = x32*x56
# x58 = 1/(x47**2 + (x51 + x57)**2)
# x59 = x58*(-x51 - x57)
# x60 = 2.0*x6
# x61 = -x17*x39 + x26 + x34*x52 + x60
# x62 = -x7
# x63 = 0.25*x4
# x64 = 0.25*x26
# x65 = x12/4
# x66 = -x17*x65 - x34*x63 + x62 + x64
# x67 = 2*x15
# x68 = x34*x39
# x69 = x14*x21
# x70 = x17*x52
# x71 = x67 - x68 - x69 - x70
# x72 = 0.25*x6
# x73 = x14*x72
# x74 = x16 + x17*x63 + x73
# x75 = x16*x34
# x76 = x43 - x75
# x77 = -x12 + x76
# x78 = x47*x58
# x79 = x37 + x48
# x80 = -x32*x79
# x81 = x18 - x52 + x54 + x9
# x82 = x14*x16
# x83 = x29 - x82
# x84 = x24 + x6 + x83
# x85 = 0.25*x40
# x86 = x17*x72
# x87 = -x14*x63 - x27 - x85 + x86
# x88 = x34*x72
# x89 = 0.25*x12
# x90 = 0.25*x53
# x91 = x4/2
# x92 = x12 + x75
# x93 = -x14*x91 + x41 + x92
# x94 = -x32*x93
# x95 = -x21
# x96 = -x34*x91 + x83 + x95
# x97 = -x34*x89
# x98 = x4/4
# x99 = x16 - x17*x98 - x73 + x97
# x100 = x19 - x4 - x54 + x9
# x101 = dt*x31
# x102 = 2.0*x4
# x103 = -x101*x102
# x104 = dt*x52
# x105 = x104*x56
# x106 = x25/2
# x107 = x106*x71
# x108 = dt*x44
# x109 = -x25*x32
# x110 = x25*x56
# x111 = 2.0*x12
# x112 = x101*x111
# x113 = dt*x56
# x114 = -x113*x39
# x115 = x71*x8
# x116 = 1/sqrt(1 - (-x32*x50 + x45*x56)**2)
# x117 = x111 - x14*x52 + x17*x21 + x40
# x118 = -x14*x65 + x22 - x88 - x90
# x119 = -x67 + x68 + x69 + x70
# x120 = -x24 + x82 + x95
# x121 = x74 + x97
# x122 = -x14*x98 + x27 + x85 + x86
# x123 = x117*x28
# x124 = x101*x21 - x105
# x125 = x106*x117
# x126 = x113*x21
# x127 = x101*x52
# x128 = 2*x56
# x129 = x46 - 2*x56**2
# x130 = x128*x50
# x131 = x31*x45
# x132 = 1/(x129**2 + (x130 + x131)**2)
# x133 = x132*(-x130 - x131)
# x134 = x129*x132
# x135 = x11**2
# x136 = x3**2
# x137 = x1**2
# x138 = 1.0*x5**2
# x139 = G/(x135*x136 + x135*x138 + 1.0*x136*x137 + x137*x138)
# x140 = x139*x22
# x141 = x139*x7
# x142 = tan(roll)
# x143 = cos(heading)
# x144 = x142*x143
# x145 = x141*x144
# x146 = -x145
# x147 = x13*x139
# x148 = sin(heading)
# x149 = x142*x148
# x150 = x142**2 + 1
# x151 = x139*x52
# x152 = x143*x151
# x153 = x139*x15
# x154 = x148*x153
# x155 = x140 + x146 + x147*x149 + x150*x152 - x150*x154
# x156 = x139*x21
# x157 = x142*x152 - x142*x154 + x156
# x158 = x157/2
# x159 = x143*x150
# x160 = x139*x39
# x161 = x148*x150
# x162 = x139*x16
# x163 = x140*x144 - x149*x162
# x164 = x141 + x163
# x165 = x156*x159 - x160*x161 + x164
# x166 = -x162
# x167 = -x141*x149
# x168 = x143*x153
# x169 = -x144*x147 + x150*x168 + x151*x161 + x166 + x167
# x170 = x142*x168 + x149*x151 - x160
# x171 = x170*x7
# x172 = x144*x162
# x173 = x140*x149
# x174 = -x172 - x173
# x175 = x147 - x156*x161 - x159*x160 + x174
# x176 = x144*x156 - x149*x160 - x151
# x177 = x16*x176
# x178 = -x144*x160 - x149*x156 - x153
# x179 = x177 - x178*x22
# x180 = x139*x27
# x181 = -x144*x180 + x167
# x182 = x162 + x181
# x183 = -x141 + x163
# x184 = x157*x7
# x185 = x16*x178
# x186 = x172 + x173 + x180
# x187 = x149*x180
# x188 = x140 + x145 - x187
# x189 = x176*x22
# x190 = x174 + x180
# x191 = x16*x170
# x192 = x166 + x181
# x193 = x139*x91 + x146 + x187
# x194 = -x176*x7
# x195 = x170/2
# x196 = x157*x27 + x171
# x197 = x157*x16
# x198 = x178*x7
# x199 = x176*x27
# x200 = x178/2
# F[0, 0] = x59*(x33 - x38*x45) + x78*(x20*x56 + x44*x77 + x61*x66 + x71*(-x34*x65 + x74))
# F[0, 1] = x59*(-x45*x81 + x80) + x78*(x44*x84 + x56*x79 + x61*x87 + x71*(x14*x89 - x22 + x88 + x90))
# F[0, 2] = x59*(-x45*x96 + x94) + x78*(x100*x44 + x56*x93 + x61*x99 + x71*(x17*x89 - x34*x98 + x62 - x64))
# F[0, 6] = x59*(x103 - x25*x45) + x78*(x105 + x107 - x108*x39 - x61*x8)
# F[0, 7] = x59*(x102*x108 + x109) + x78*(-x108*x21 + x110 - x23*x71 + x28*x61)
# F[0, 8] = x59*(-x108*x60 + x112) + x78*(-x104*x44 + x106*x61 + x114 + x115)
# F[1, 0] = -x116*(x117*x66 + x118*x119 + x31*(-x41 + x42 + x92) + x38*x56)
# F[1, 1] = -x116*(x117*x87 + x119*x121 + x31*(x120 + x30) + x56*x81)
# F[1, 2] = -x116*(x117*x99 + x119*x122 + x31*(x18 + x4 + x55) + x56*x96)
# F[1, 6] = -x116*(x101*x39 + x110 - x117*x8 + x119*x23)
# F[1, 7] = -x116*(x106*x119 + x123 + x124)
# F[1, 8] = -x116*(-x119*x28 + x125 + x126 + x127)
# F[2, 0] = x133*(-x128*(x120 - x13*x17) + x33) + x134*(x117*x118 + x31*x38 + x56*x77 + x66*x71)
# F[2, 1] = x133*(-x128*(-x39 + x76) + x80) + x134*(x117*x121 + x31*x81 + x56*x84 + x71*x87)
# F[2, 2] = x133*(-x128*(-x17*x91 + x49) + x94) + x134*(x100*x56 + x117*x122 + x31*x96 + x71*x99)
# F[2, 6] = x133*(x103 + x113*x60) + x134*(x114 - x115 + x117*x23 + x25*x31)
# F[2, 7] = x133*(x109 - x111*x113) + x134*(x125 - x126 - x127 + x28*x71)
# F[2, 8] = x133*(x112 - x113*x67) + x134*(x107 - x123 + x124)
# F[3, 0] = -x12*x158 + x15*x155 + x165*x39 + x169*x52 - x171 - x175*x21 + x179
# F[3, 1] = x15*x182 - x170*x27 - x183*x21 + x184 - x185 + x186*x39 + x188*x52 - x189
# F[3, 2] = x15*x190 - x158*x4 + x164*x52 - x178*x27 + x191 + x192*x39 - x193*x21 + x194
# F[4, 0] = -x12*x195 + x15*x169 - x155*x52 + x165*x21 + x175*x39 + x184 + x185 + x189
# F[4, 1] = x15*x188 + x179 - x182*x52 + x183*x39 + x186*x21 + x196
# F[4, 2] = x15*x164 - x190*x52 + x192*x21 + x193*x39 - x195*x4 - x197 - x198 + x199
# F[5, 0] = -x12*x200 + x15*x175 + x155*x21 + x157*x22 + x165*x52 - x169*x39 - x191 + x194
# F[5, 1] = x15*x183 + x170*x22 + x182*x21 + x186*x52 - x188*x39 + x197 + x198 - x199
# F[5, 2] = x15*x193 - x164*x39 + x177 + x190*x21 + x192*x52 + x196 - x200*x4
# F[6, 6] = 1
# F[7, 7] = 1
# F[8, 8] = 1

# %% [markdown]
# ## Mag Update
#
#
# Kalman equation:
# $$y = z - h(x)$$
# innovation = measurement - (func translating state to measurement)

# %%
q = euler2q(roll, pitch, heading)

mag_inertial = (q * quaternion.Quaternion.from_vec(np.array([mx, my, mz])) * q.inv()).as_ndarray()[1:]
mag_inertial[2] = 0
mag_inertial /= sqrt(mag_inertial[0]**2 + mag_inertial[1]**2)


mag_body = (q.inv() * quaternion.Quaternion.from_vec(mag_inertial) * q).as_ndarray()[1:]

# Only portion that we need to determine Jacobian is transfering "north vector"
# to body coordinates

h = (q.inv() * quaternion.Quaternion.from_vec(np.array([1.0, 0, 0])) * q).as_ndarray()[1:]

y = mag_body - h
H = np.zeros((2, len(state)), dtype=object)
for n in range(2):
    for m in range(len(state)):
        tmp = diff(h[n], state[m])
        H[n, m] = tmp
        if tmp != 0:
            tmp = tmp
            print(f"H[{n}, {m}] = {tmp}")
# Out:
# H[0, 0] = -1.0*(-0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - 1.0*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2*(-(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(sin(heading/2)*sin(pitch/2)*cos(roll/2) - sin(roll/2)*cos(heading/2)*cos(pitch/2)) - (sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2)) - (-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)**2 + 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(sin(heading/2)*sin(pitch/2)*cos(roll/2) - sin(roll/2)*cos(heading/2)*cos(pitch/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - 1.0*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(sin(heading/2)*sin(pitch/2)*cos(roll/2) - sin(roll/2)*cos(heading/2)*cos(pitch/2)) - (sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2)) - (-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll ...
# H[0, 1] = 1.0*(-0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + 1.0*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2*(-(-1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(sin(heading/2)*sin(roll/2)*cos(pitch/2) - sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)**2 + 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(sin(heading/2)*sin(roll/2)*cos(pitch/2) - sin(pitch/2)*cos(heading/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - 1.0*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-(-1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(sin(heading/2)*sin(roll/2)*cos(pitch/2) - sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(rol ...
# H[0, 2] = 1.0*(-0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + 1.0*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) + 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2*(-(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-sin(heading/2)*cos(pitch/2)*cos(roll/2) + sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + sin(roll/2)*cos(heading/2)*cos(pitch/2))*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)**2 + 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-sin(heading/2)*cos(pitch/2)*cos(roll/2) + sin(pitch/2)*sin(roll/2)*cos(heading/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - 1.0*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-sin(heading/2)*cos(pitch/2)*cos(roll/2) + sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + sin(roll/2)*cos(heading/2)*cos(pitch/2))*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin( ...
# H[1, 0] = -1.0*(-0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - 1.0*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 0.5*sin(pitch/2)*cos(heading/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(0.5*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 0.5*sin(pitch/2)*cos(heading/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) + 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(-(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(sin(heading/2)*sin(pitch/2)*cos(roll/2) - sin(roll/2)*cos(heading/2)*cos(pitch/2)) - (sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2)) - (-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))*(sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)**2 - 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(-(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(sin(heading/2)*sin(pitch/2)*cos(roll/2) - sin(roll/2)*cos(heading/2)*cos(pitch/2)) - (sin(heading/2)*sin(pitch/2)*sin(rol ...
# H[1, 1] = -1.0*(-0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - 1.0*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) + 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(-(-1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(sin(heading/2)*sin(roll/2)*cos(pitch/2) - sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)**2 - 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(-(-1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (1.0*sin(heading/ ...
# H[1, 2] = 1.0*(-0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) - 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) - 1.0*(0.5*sin(heading/2)*sin(pitch/2)*sin(roll/2) + 0.5*cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2) + 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) + 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(-(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-sin(heading/2)*cos(pitch/2)*cos(roll/2) + sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + sin(roll/2)*cos(heading/2)*cos(pitch/2))*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)**2 - 1.0*(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))*(-(1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(-sin(heading/2)*cos(pitch/2)*cos(roll/2) + sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))*(1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + sin(roll/2)*cos(heading/2)*cos(pitch/2))*(1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)) - (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(-1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) - 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2)))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading/2)*cos(pitch/2)*cos(roll/2))**2 + (-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))**2 + (1.0*sin(heading/2)*sin(roll/2)*cos(pitch/2) + 1.0*sin(pitch/2)*cos(heading/2)*cos(roll/2))**2 + (1.0*sin(heading/2)*cos(pitch/2)*cos(roll/2) - 1.0*sin(pitch/2)*sin(roll/2)*cos(heading/2))**2)**2 - 1.0*(-1.0*sin(heading/2)*sin(pitch/2)*cos(roll/2) + 1.0*sin(roll/2)*cos(heading/2)*cos(pitch/2))*(0.5*sin(heading/2)*sin(pitch/2)*cos(roll/2) - 0.5*sin(roll/2)*cos(heading/2)*cos(pitch/2))/((1.0*sin(heading/2)*sin(pitch/2)*sin(roll/2) + cos(heading ...

# %%
subexprs = {sin(pitch/2): 0, cos(pitch/2): 1.0}
for m in range(2):
    for n in range(len(state)):
        for k, v in subexprs.items():
            H[m, n] = H[m, n].subs(k, v)
subexprs, subs = cse(H.flatten())
subs = np.reshape(subs, (2, 9))   

for se in subexprs:
    print(f"{se[0]} = {(se[1])}")
    
for n in range(2):
    for m in range(len(state)):
        tmp = subs[n, m]
        if tmp != 0:
            print(f"H[{n}, {m}] = {(tmp)}")  # ccode
# Out:
# x0 = roll/2
# x1 = sin(x0)
# x2 = x1**2
# x3 = heading/2
# x4 = sin(x3)
# x5 = x4**2
# x6 = 1.0*x5
# x7 = x2*x6
# x8 = cos(x0)
# x9 = x8**2
# x10 = x6*x9
# x11 = cos(x3)
# x12 = x11**2
# x13 = 1.0*x12
# x14 = x13*x2
# x15 = x13*x9
# x16 = 1/(x10 + x14 + x15 + x7)
# x17 = 2.0*x16
# x18 = x11*x4
# x19 = x17*x18
# x20 = x1*x8
# x21 = x17*x20
# H[0, 2] = -x19*x2 - x19*x9
# H[1, 0] = 4.0*x16*x18*x20
# H[1, 1] = x12*x21 - x21*x5
# H[1, 2] = x10*x16 + x14*x16 - x15*x16 - x16*x7
